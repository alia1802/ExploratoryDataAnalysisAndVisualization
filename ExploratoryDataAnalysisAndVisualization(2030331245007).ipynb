# %%
Name: Alia Ibrahim Bandarkar
    PRN NO: 2030331245007

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 1. countplot/ Barchart

# %%
sns.countplot(x='Survived', data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived', data=df,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# # 2 line chart basically used for numeric type of variable

# %%
sns.lineplot(x='Age',y='Fare',data=df,color="maroon")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# # 3. scatter plot

# %%
df.plot.scatter('Age','Fare',color="black")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
df.plot.scatter('Age','Survived',color="red")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %% [markdown]
# # 4 Histogram

# %%
df['Age'].hist(bins=8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5 Pie chart

# %%
import matplotlib.pyplot as plt
sizes=df['Survived'].value_counts()
fig1,ax1=plt.subplots()
ax1.pie(sizes,labels=['Not Survived','Survived'],autopct='%1.1f%%',shadow=True)
plt.show()
